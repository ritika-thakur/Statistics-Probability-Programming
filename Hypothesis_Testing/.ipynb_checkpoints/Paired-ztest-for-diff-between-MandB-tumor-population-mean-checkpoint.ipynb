# %%
import pandas as pd

# %%
data = pd.read_csv("./data.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
M_feature_values = data[data['diagnosis'] == 'M']['radius_mean']

# %%
B_feature_values = data[data['diagnosis'] == 'B']['radius_mean']

# %%
M_feature_values
# Out:
# 0      17.99
# 1      20.57
# 2      19.69
# 3      11.42
# 4      20.29
# 5      12.45
# 6      18.25
# 7      13.71
# 8      13.00
# 9      12.46
# 10     16.02
# 11     15.78
# 12     19.17
# 13     15.85
# 14     13.73
# 15     14.54
# 16     14.68
# 17     16.13
# 18     19.81
# 22     15.34
# 23     21.16
# 24     16.65
# 25     17.14
# 26     14.58
# 27     18.61
# 28     15.30
# 29     17.57
# 30     18.63
# 31     11.84
# 32     17.02
#        ...
# 444    18.03
# 446    17.75
# 449    21.10
# 451    19.59
# 460    17.08
# 461    27.42
# 468    17.60
# 479    16.25
# 487    19.44
# 489    16.69
# 492    18.01
# 498    18.49
# 499    20.59
# 501    13.82
# 503    23.09
# 509    15.46
# 512    13.40
# 514    15.05
# 516    18.31
# 517    19.89
# 521    24.63
# 533    20.47
# 535    20.55
# 536    14.27
# 562    15.22
# 563    20.92
# 564    21.56
# 565    20.13
# 566    16.60
# 567    20.60
# Name: radius_mean, Length: 212, dtype: float64

# %%
B_feature_values
# Out:
# 19     13.540
# 20     13.080
# 21      9.504
# 37     13.030
# 46      8.196
# 48     12.050
# 49     13.490
# 50     11.760
# 51     13.640
# 52     11.940
# 55     11.520
# 58     13.050
# 59      8.618
# 60     10.170
# 61      8.598
# 63      9.173
# 66      9.465
# 67     11.310
# 68      9.029
# 69     12.780
# 71      8.888
# 74     12.310
# 76     13.530
# 79     12.860
# 80     11.450
# 81     13.340
# 84     12.000
# 88     12.360
# 89     14.640
# 90     14.620
#         ...
# 530    11.750
# 531    11.670
# 532    13.680
# 534    10.960
# 537    11.690
# 538     7.729
# 539     7.691
# 540    11.540
# 541    14.470
# 542    14.740
# 543    13.210
# 544    13.870
# 545    13.620
# 546    10.320
# 547    10.260
# 548     9.683
# 549    10.820
# 550    10.860
# 551    11.130
# 552    12.770
# 553     9.333
# 554    12.880
# 555    10.290
# 556    10.160
# 557     9.423
# 558    14.590
# 559    11.510
# 560    14.050
# 561    11.200
# 568     7.760
# ...

# %%
from statsmodels.stats.weightstats import ztest

# %%
result = ztest(M_feature_values, B_feature_values)

# %%
 result
# Out:
# (25.435821610057054, 1.0131691292988755e-142)
