# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.shape
# Out:
# (569, 33)

# %%
filtered_data = data.drop([data.columns[0], data.columns[32]], axis=1)

# %%
filtered_data.shape
# Out:
# (569, 31)

# %%
B_data = filtered_data[filtered_data['diagnosis'] == 'B']

# %%
M_data = filtered_data[filtered_data['diagnosis'] == 'M']

# %%
B_data = B_data.iloc[:,0:2]

# %%
M_data = M_data.iloc[:,0:2]

# %%
training_data_len = int(0.7 * len(filtered_data))

# %%
training_data_len
# Out:
# 398

# %%
category_data_len = training_data_len//2

# %%
category_data_len
# Out:
# 199

# %%
B_training_data = B_data.iloc[0:category_data_len,:]

# %%
B_training_data
# Out:
#     diagnosis  radius_mean
# 19          B       13.540
# 20          B       13.080
# 21          B        9.504
# 37          B       13.030
# 46          B        8.196
# 48          B       12.050
# 49          B       13.490
# 50          B       11.760
# 51          B       13.640
# 52          B       11.940
# 55          B       11.520
# 58          B       13.050
# 59          B        8.618
# 60          B       10.170
# 61          B        8.598
# 63          B        9.173
# 66          B        9.465
# 67          B       11.310
# 68          B        9.029
# 69          B       12.780
# 71          B        8.888
# 74          B       12.310
# 76          B       13.530
# 79          B       12.860
# 80          B       11.450
# 81          B       13.340
# 84          B       12.000
# 88          B       12.360
# 89          B       14.640
# 90          B       14.620
# ..        ...          ...
# 318         B        9.042
# 319         B       12.430
# ...

# %%
M_training_data = M_data.iloc[0:category_data_len,:]

# %%
M_training_data
# Out:
#     diagnosis  radius_mean
# 0           M        17.99
# 1           M        20.57
# 2           M        19.69
# 3           M        11.42
# 4           M        20.29
# 5           M        12.45
# 6           M        18.25
# 7           M        13.71
# 8           M        13.00
# 9           M        12.46
# 10          M        16.02
# 11          M        15.78
# 12          M        19.17
# 13          M        15.85
# 14          M        13.73
# 15          M        14.54
# 16          M        14.68
# 17          M        16.13
# 18          M        19.81
# 22          M        15.34
# 23          M        21.16
# 24          M        16.65
# 25          M        17.14
# 26          M        14.58
# 27          M        18.61
# 28          M        15.30
# 29          M        17.57
# 30          M        18.63
# 31          M        11.84
# 32          M        17.02
# ..        ...          ...
# 385         M        14.60
# 389         M        19.55
# ...

# %%
B_test_data = B_data.iloc[category_data_len:,:]

M_test_data = M_data.iloc[category_data_len:,:]

# %%
testing_data = pd.concat([B_test_data, M_test_data])

# %%
testing_data
# Out:
#     diagnosis  radius_mean
# 360         B       12.540
# 361         B       13.300
# 362         B       12.760
# 363         B       16.500
# 364         B       13.400
# 367         B       12.210
# 371         B       15.190
# 374         B       13.690
# 375         B       16.170
# 376         B       10.570
# 377         B       13.460
# 378         B       13.660
# 380         B       11.270
# 381         B       11.040
# 382         B       12.050
# 383         B       12.390
# 384         B       13.280
# 386         B       12.210
# 387         B       13.880
# 388         B       11.270
# 390         B       10.260
# 391         B        8.734
# 394         B       12.100
# 395         B       14.060
# 396         B       13.510
# 397         B       12.800
# 398         B       11.060
# 399         B       11.800
# 401         B       11.930
# 402         B       12.960
# ..        ...          ...
# 546         B       10.320
# 547         B       10.260
# ...

# %%
training_data = pd.concat([B_training_data, M_training_data])

# %%
training_data
# Out:
#     diagnosis  radius_mean
# 19          B       13.540
# 20          B       13.080
# 21          B        9.504
# 37          B       13.030
# 46          B        8.196
# 48          B       12.050
# 49          B       13.490
# 50          B       11.760
# 51          B       13.640
# 52          B       11.940
# 55          B       11.520
# 58          B       13.050
# 59          B        8.618
# 60          B       10.170
# 61          B        8.598
# 63          B        9.173
# 66          B        9.465
# 67          B       11.310
# 68          B        9.029
# 69          B       12.780
# 71          B        8.888
# 74          B       12.310
# 76          B       13.530
# 79          B       12.860
# 80          B       11.450
# 81          B       13.340
# 84          B       12.000
# 88          B       12.360
# 89          B       14.640
# 90          B       14.620
# ..        ...          ...
# 385         M       14.600
# 389         M       19.550
# ...

# %%
M_train_features = training_data[training_data['diagnosis'] == 'M']['radius_mean']

# %%
B_train_features = training_data[training_data['diagnosis'] == 'B']['radius_mean']

# %%
import matplotlib.pyplot as plt 

import seaborn as sns

import numpy as np

# %%
plt.hist(M_train_features)

plt.xlabel('radius_mean|diagnosis=M')

plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import scipy.stats as s

# %%
sns.distplot(M_train_features,kde=False,fit=s.norm)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(M_train_features,kde=False,fit=s.rayleigh)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def normal_likelihood(training_features):
    
    training_features = np.array(training_features)
    
    mu_cap = np.mean(training_features)
    
    sigma_cap = np.std(training_features)
    
    return -np.sum(np.log(s.norm.pdf(mu_cap, sigma_cap, training_features)))

# %%
def rayleigh_likelihood(training_features):
    
    training_features = np.array(training_features)
    
    sigma_cap = np.sqrt(np.mean(training_features**2)/2)
    
    return -np.sum(np.log(s.rayleigh.pdf(sigma_cap, training_features)))

# %%
def determine_distribution(training_features):
    
    if normal_likelihood(training_features) < rayleigh_likelihood(training_features):
        
        return (np.mean(training_features), np.std(training_features))
    
    else: 
        
        return np.sqrt(np.mean(training_features**2)/2)

# %%
M_parameters = determine_distribution(M_train_features)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
M_parameters
# Out:
# (17.356381909547743, 3.185799991020829)

# %%
B_parameters = determine_distribution(B_train_features)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
B_parameters
# Out:
# (11.984396984924626, 1.7105967450900044)
